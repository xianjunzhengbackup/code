# %%
import folium

# %%
site={}

# %%
site['home']=[-35.1599026,149.0961]

# %%
site['work']=[-35.3657955,149.0947059]

# %%
site['abc drink:45']=[-35.2601358,149.1334806]

# %%
site['Boral Mugga lane drink:25']=[-35.367476,149.132060]

# %%
site['Harvey normal Fyshwick drink:23']=[-35.32637,149.166656]

# %%
site['Lennock motors Phillip drink:61']=[-35.3571955,149.0891763]

# %%
site['Maddox house Barton drink:32']=[-35.3079303,149.1336224]

# %%
site['Pinnacle appartments Kingston drink:59']=[-35.3180802,149.1399596]

# %%
site['Target civic snack:39']=[-35.28028,149.134957,15]

# %%
site['Calvary retirement home drink:106']=[-35.250192,149.087947]

# %%
site['BOC gas Fyshwick :20']=[-35.3303093,149.1742984]

# %%
for item in site:
    print(site[item])
# Out:
# [-35.3303093, 149.1742984]
# [-35.28028, 149.134957, 15]
# [-35.3571955, 149.0891763]
# [-35.3079303, 149.1336224]
# [-35.32637, 149.166656]
# [-35.1599026, 149.0961]
# [-35.250192, 149.087947]
# [-35.3180802, 149.1399596]
# [-35.2601358, 149.1334806]
# [-35.367476, 149.13206]
# [-35.3657955, 149.0947059]

# %%
gungahlin = folium.Map(location=[-35.187746,149.1201253],zoom_start=11)

# %%
for item in site:
    a_site=folium.Marker(site[item],popup=item)
    a_site.add_to(gungahlin)

# %%
gungahlin
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
