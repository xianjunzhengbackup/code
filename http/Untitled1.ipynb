# %%
import requests
import json

# %%
url='http://catalog.data.gov/api/3/action/package_search'

# %%
request_string={'q':'query','start':192680,'rows':100}

# %%
req=requests.get('http://httpbin.org/get',params=request_string)

# %%
print(req.text)
# Out:
# {
#   "args": {
#     "q": "query",
#     "rows": "100",
#     "start": "192680"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Connection": "close",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.12.4"
#   },
#   "origin": "130.56.94.37",
#   "url": "http://httpbin.org/get?q=query&start=192680&rows=100"
# }

# %%
req=requests.get(url,data=json.dumps(request_string))

# %%
print(req.text)
# Out:
# {"help": "https://catalog.data.gov/api/3/action/help_show?name=package_search", "success": true, "result": {"count": 192686, "sort": "views_recent desc", "facets": {}, "results": [{"license_title": "License not specified", "maintainer": "devops@cfpb.gov", "relationships_as_object": [], "private": false, "maintainer_email": "devops@cfpb.gov", "num_tags": 12, "id": "1e68f387-5f1c-46c0-a0d1-46044ffef5bf", "metadata_created": "2014-02-26T00:48:24.897497", "metadata_modified": "2015-09-26T08:07:59.498823", "author": "", "author_email": "", "state": "active", "version": null, "creator_user_id": "47303a9e-1187-4290-85a3-1fc02dc49e4a", "type": "dataset", "resources": [{"cache_last_updated": null, "package_id": "1e68f387-5f1c-46c0-a0d1-46044ffef5bf", "webstore_last_updated": null, "id": "2f297213-7198-4be1-af1e-2d2623e7f6e9", "size": null, "state": "active", "hash": "", "description": "", "format": "CSV", "tracking_summary": {"total": 13465, "recent": 25}, "last_modified": null, "url_type": n
# ...

# %%
resp_json=req.json()

# %%
type(resp_json)
# Out:
# dict

# %%
resp_json['result']['count']
# Out:
# 192686
