# %%
time echo {1..5} | xargs -n 1 -P 5 sleep
# Out:
# real	0m5.005s
# user	0m0.000s
# sys	0m0.005s

# %%
xargs --help
# Out:
# Usage: xargs [OPTION]... COMMAND [INITIAL-ARGS]...
# Run COMMAND with arguments INITIAL-ARGS and more arguments read from input.
#
# Mandatory and optional arguments to long options are also
# mandatory or optional for the corresponding short option.
#   -0, --null                   items are separated by a null, not whitespace;
#                                  disables quote and backslash processing and
#                                  logical EOF processing
#   -a, --arg-file=FILE          read arguments from FILE, not standard input
#   -d, --delimiter=CHARACTER    items in input stream are separated by CHARACTER,
#                                  not by whitespace; disables quote and backslash
#                                  processing and logical EOF processing
#   -E END                       set logical EOF string; if END occurs as a line
#                                  of input, the rest of the input is ignored
# ...

# %%
time echo {1..5} | xargs -n 1 -P 5 echo
#-n 1 每次只读入一个参数
# -P 5 分配5个CPU
# Out:
# 1
# 2
# 3
# 4
# 5
#
# real	0m0.009s
# user	0m0.001s
# sys	0m0.007s

# %%
time seq 77 80 | parallel wget http://www.gutenberg.org/cache/epub/{}/pg{}.txt
#并行下载文件
#其中{}是占位符，用来占位传入参数的位置。
# Out:
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; and it won't cost you a cent.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --bibtex'.
#
# --2017-01-20 20:27:26--  http://www.gutenberg.org/cache/epub/79/pg79.txt
# Resolving www.gutenberg.org... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org|152.19.134.47|:80... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: http://www.gutenberg.org/w/captcha/question/ [following]
# --2017-01-20 20:27:27--  http://www.gutenberg.org/w/captcha/question/
# Reusing existing connection to www.gutenberg.org:80.
# ...

# %%
time seq 77 80 | awk '{print "http://www.gutenberg.org/cache/epub/"$1"/pg"$1".txt"}' | parallel wget
# Out:
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; and it won't cost you a cent.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --bibtex'.
#
# --2017-01-20 20:26:53--  http://www.gutenberg.org/cache/epub/80/pg80.txt
# Resolving www.gutenberg.org... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org|152.19.134.47|:80... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: http://www.gutenberg.org/w/captcha/question/ [following]
# --2017-01-20 20:26:54--  http://www.gutenberg.org/w/captcha/question/
# Reusing existing connection to www.gutenberg.org:80.
# ...

# %%
time for x in `cat download_link.txt`; do echo $x; done
# Out:
# http://www.gutenberg.org/cache/epub/1/pg1.txt
# http://www.gutenberg.org/cache/epub/2/pg2.txt
# http://www.gutenberg.org/cache/epub/3/pg3.txt
# http://www.gutenberg.org/cache/epub/4/pg4.txt
# http://www.gutenberg.org/cache/epub/5/pg5.txt
# http://www.gutenberg.org/cache/epub/6/pg6.txt
# http://www.gutenberg.org/cache/epub/7/pg7.txt
# http://www.gutenberg.org/cache/epub/8/pg8.txt
# http://www.gutenberg.org/cache/epub/9/pg9.txt
# http://www.gutenberg.org/cache/epub/10/pg10.txt
# http://www.gutenberg.org/cache/epub/11/pg11.txt
# http://www.gutenberg.org/cache/epub/12/pg12.txt
# http://www.gutenberg.org/cache/epub/13/pg13.txt
# http://www.gutenberg.org/cache/epub/14/pg14.txt
# http://www.gutenberg.org/cache/epub/15/pg15.txt
# http://www.gutenberg.org/cache/epub/16/pg16.txt
# http://www.gutenberg.org/cache/epub/17/pg17.txt
# http://www.gutenberg.org/cache/epub/18/pg18.txt
# http://www.gutenberg.org/cache/epub/19/pg19.txt
# http://www.gutenberg.org/cache/epub/20/pg20.txt
# ...

# %%
time cat download_link.txt | parallel echo {}
# Out:
# Academic tradition requires you to cite works you base your article on.
# When using programs that use GNU Parallel to process data for publication
# please cite:
#
#   O. Tange (2011): GNU Parallel - The Command-Line Power Tool,
#   ;login: The USENIX Magazine, February 2011:42-47.
#
# This helps funding further development; and it won't cost you a cent.
# If you pay 10000 EUR you should feel free to use GNU Parallel without citing.
#
# To silence the citation notice: run 'parallel --bibtex'.
#
# http://www.gutenberg.org/cache/epub/1/pg1.txt
# http://www.gutenberg.org/cache/epub/2/pg2.txt
# http://www.gutenberg.org/cache/epub/3/pg3.txt
# http://www.gutenberg.org/cache/epub/4/pg4.txt
# http://www.gutenberg.org/cache/epub/5/pg5.txt
# http://www.gutenberg.org/cache/epub/6/pg6.txt
# http://www.gutenberg.org/cache/epub/7/pg7.txt
# http://www.gutenberg.org/cache/epub/8/pg8.txt
# http://www.gutenberg.org/cache/epub/9/pg9.txt
# http://www.gutenberg.org/cache/epub/10/pg10.txt
# ...
